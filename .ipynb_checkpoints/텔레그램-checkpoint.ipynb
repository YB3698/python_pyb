# %% [markdown]
# # 텔레그램 봇

# %%
# !pip install python-telegram-bot

# %%
import asyncio
import nest_asyncio # 주피터랩용
from dotenv import load_dotenv
import os
#.env 업로드
load_dotenv()
from telegram import Update
from telegram.ext import Application, CommandHandler, MessageHandler, filters, CallbackContext
nest_asyncio.apply()

TELEGRAM_TOKEN =os.getenv("TELEGRAM_TOKEN")

async def start( update, context):
    await context.bot.send_message(chat_id=update.effective_chat.id, text="봇이 가동되었습니다!")

async def handle_message(update , context ):
    user_message = update.message.text.lower()  # Text -> text

    if "안녕" in user_message:
        response = "안녕하세요!"
    elif "날씨" in user_message:
        response = "이번주는 계속 추울 것 같아요ㅜㅠ 다음주부터 따뜻해진대요!"
    elif "배고" in user_message:
        response = "ㅜㅠ 어뜩하져 안타깝지만 좀만 더 참으세요"
    elif "심심" in user_message:
        response = "심심하시다구여?? 머하구 놀아드릴까요!!"
    elif "고민" in user_message:
        response = "저한테 말씀해보세요! 제가 해결해드릴 순 없겠지만 말하다보면 고민이 해결될 수도 있어요. 뭐든 들어드릴게요"
    elif "혜빈" in user_message:
        response = "그게 누구죠? 사람은 맞나요?"
    elif "저녁 추천" in user_message:
        response = "고민될 땐 치킨이죠!"
    print(response)

    #응답 메세지 전송
    await context.bot.send_message(chat_id=update.effective_chat.id, text=response)

async def main():
    application = Application.builder().token(TELEGRAM_TOKEN).build()
    await application.initialize() # 초기화 필수

    # 핸들러 추가
    application.add_handler(CommandHandler("start", start))
    application.add_handler(MessageHandler(filters.TEXT & ~filters.COMMAND, handle_message))
    
    await application.start()
    print("봇이 실행중 입니다.")

    await application.updater.start_polling()

if __name__ == "__main__":
    asyncio.run(main())
# Out:
# 봇이 실행중 입니다.
# Exception happened while polling for updates.
# Traceback (most recent call last):
#   File "C:\Dev\Lang\Python313\Lib\site-packages\telegram\ext\_updater.py", line 750, in _network_loop_retry
#     if not await do_action():
#            ^^^^^^^^^^^^^^^^^
#   File "C:\Dev\Lang\Python313\Lib\site-packages\telegram\ext\_updater.py", line 744, in do_action
#     return action_cb_task.result()
#            ~~~~~~~~~~~~~~~~~~~~~^^
#   File "C:\Dev\Lang\Python313\Lib\asyncio\futures.py", line 199, in result
#     raise self._exception.with_traceback(self._exception_tb)
#   File "C:\Dev\Lang\Python313\Lib\asyncio\tasks.py", line 304, in __step_run_and_handle_result
#     result = coro.send(None)
#   File "C:\Dev\Lang\Python313\Lib\site-packages\telegram\ext\_updater.py", line 371, in polling_action_cb
#     updates = await self.bot.get_updates(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<7 lines>...
#     )
#     ^
# ...
