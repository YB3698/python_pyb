# %%
import cx_Oracle
import requests as req
from bs4 import BeautifulSoup as bs

# ✅ DB 연결 정보 설정
sid = 'XE'
host = '210.119.14.76'
port = 1521
username = 'kiosk'
password = '12345'

# 🔹 오라클 DB 연결
conn = cx_Oracle.connect(f'{username}/{password}@{host}:{port}/{sid}')
cursor = conn.cursor()

# 🔹 크롤링한 데이터 리스트
db_name_list = []
db_exp_list = []
db_img_list = []

url = "https://ediya.com/inc/ajax_brand.php"
params = {"gubun": "menu_more", "product_cate": "7", "chked_val": "", "skeyword": "", "page": 1}
page = 1

while True:
    print(f'{page}페이지 실행', '\n')
    params["page"] = page
    response = req.get(url, params=params)

    if response.status_code != 200 or "데이터 끝" in response.text or page == 23:
        break

    soup = bs(response.text, 'html.parser')

    # 🔹 메뉴 이름
    # names = [name.text.strip().split('<span')[0] for name in soup.find_all("h2")]
    # db_name_list.extend(names)

    names = soup.find_all("h2")
    for a in range(len(names)):
        names[a] = str(names[a]).split('<span')[0].replace('<h2>', '').strip()
        db_name_list.append(names[a])

    # 🔹 메뉴 설명
    detail = soup.find_all("div", class_="detail_txt")
    for b in range(len(detail)):
        detail[b] = str(detail[b].text).replace('\\u200b','').replace('\\xa0', '')
        db_exp_list.append(detail[b])

    # 🔹 이미지 링크
    src_value = soup.find_all("img", alt="")
    src_img = [img['src'] for img in src_value]
    
    for v in range(len(src_img)):
        src_img[v] = 'https://ediya.com' + src_img[v]
        db_img_list.append(src_img[v])

    page += 1

print(db_name_list, '\n')
print(db_exp_list, '\n')
print(db_img_list, '\n')
# Out:
# 1페이지 실행
#
# 2페이지 실행
#
# 3페이지 실행
#
# 4페이지 실행
#
# 5페이지 실행
#
# 6페이지 실행
#
# 7페이지 실행
#
# 8페이지 실행
#
# 9페이지 실행
#
# 10페이지 실행
#
# 11페이지 실행
#
# 12페이지 실행
#
# 13페이지 실행
#
# 14페이지 실행
#
# 15페이지 실행
#
# 16페이지 실행
#
# 17페이지 실행
#
# 18페이지 실행
#
# 19페이지 실행
#
# 20페이지 실행
#
# 21페이지 실행
#
# 22페이지 실행
#
# 23페이지 실행
#
# ['이디야 콤부차 복숭아 망고', '이디야 콤부차 청포도 레몬', '이디야 콤부차 석류애플라임', '(R) 아샷추', '(EX) 아샷추', '(R) 아망추', '(EX) 아망추', '(R) 아샷추', '(EX) 아샷추', '(R) 제로슈가 아샷추', '(R) 제로슈가 아샷추', '(R) 제로슈가 아이스티', '(L) 자몽 포멜로 에이드', '(EX)자몽 포멜로 에이드', '(L) 머스캣 모히또 에이드', '(EX) 머스캣 모히또 에이드', '(L) 감귤 레몬 에이드', '(EX) 감귤 레몬 에이드', 'HOT 디카페인 에스프레소', 'HOT 디카페인 에스프레소 마끼아또', 'HOT 디카페인 에스프레소 콘파냐', '비타민 주스 애플망고', '비타민 주스 믹스베리', '(R) 생딸기 연유 플랫치노', '(R) 생딸기 크런치 쉐이크', '(R) 딸기 망고 라떼', '(EX) 딸기 망고 라떼', '(R) ICED 생딸기 포멜로 티펀치', '(EX) ICED 생딸기 포멜로 티펀치', '(R) HOT 생딸기 포멜로 티펀치', '(EX) HOT 생딸기 포멜로 티펀치', '(L) HOT 청크 쿠키 라떼', '(L) ICED 청크 쿠키 라떼', '(EX) HOT 청크 쿠키 라떼', '(EX) ICED 청크 쿠키 라떼', '(L) HOT 청크 쿠키 라떼', '(L) ICED 청크 쿠키 라떼', '(EX) HOT 청크 쿠키 라떼', '(EX) ICED 청크 쿠키 라떼', '(L) HOT 슈크림 카라멜 라떼', '(EX) HOT 슈크림 카라멜 라떼', '(L) HOT 슈크림 카라멜 라떼', '(EX) HOT 슈크림 카라멜 라떼', '(L) ICED 슈크림 카라멜 라떼', '(EX) ICED 슈크림 카라멜 라떼', '(L) ICED 슈크림 카라멜 라떼', '(EX) ICED 슈크림 카라멜 라떼', '(R) ICED 딸기 말차 라떼', '(EX) ICED 딸기 말차 라떼', '(R) HOT 감귤 히비스커스 티', '(EX) HOT 감귤 히비스커스 티', '(R) ICED 감귤 히비스커스 티', '(EX) ICED 감귤 히비스커스 티', '(L) ICED 꿀 화이트 아메리카노', '(EX) ICED 꿀 화이트 아메리카노', '(L) ICED 꿀 화이트 아메리카노', '(EX) ICED 꿀 화이트 아메리카노', '(L) ICED 꿀 미숫커피', '(EX) ICED 꿀 미숫커피', '(R) ICED 꿀 메실 레몬티', '(EX) ICED 꿀 메실 레몬티', '(R) HOT 꿀 메실 레몬티', '(EX) HOT 꿀 메실 레몬티', '(R) HOT 토피넛 라떼', '(EX) HOT 토피넛 라떼', '(R) ICED 토피넛 라떼', '(EX) ICED 토피넛 라떼', '(R)딸기 듬뿍 라떼', '(EX)딸기 듬뿍 라떼', '(L)달달커피', '(EX)달달커피', '소프트 아이스크림', '아이스크림 카페라떼', '꿀 인절미 아이스크림', '초코쿠키 아이스크림', '딸기쿠키 아이스크림', '(L) HOT 디카페인 카페 라떼', '(EX) HOT 디카페인 카페 라떼', '(L) ICED 디카페인 카페 라떼', '(EX) ICED 디카페인 카페 라떼', '(L) ICED 디카페인 카페 아메리카노', '(EX) ICED 디카페인 카페 아메리카노', '(L) HOT 디카페인 카라멜 마끼아또', '(L) ICED 디카페인 카라멜 마끼아또', '(EX) HOT 디카페인 카라멜 마끼아또', '(EX) ICED 디카페인 카라멜 마끼아또', '(L) ICED 디카페인 넛츠 크림 라떼', '(L) HOT 디카페인 연유 카페 라떼', '(L) ICED 디카페인 연유 카페 라떼', '(EX) HOT 디카페인 연유 카페 라떼', '(EX) ICED 디카페인 연유 카페 라떼', '(L) HOT 디카페인 카페 모카', '(L) ICED 디카페인 카페 모카', '(EX) HOT 디카페인 카페 모카', '(EX) ICED 디카페인 카페 모카', '(L) HOT 디카페인 바닐라 라떼', '(L) ICED 디카페인 바닐라 라떼', '(EX) HOT 디카페인 바닐라 라떼', '(EX) ICED 디카페인 바닐라 라떼', '(L) HOT 디카페인 화이트 초콜릿 모카', '(L) ICED 디카페인 화이트 초콜릿 모카', '(EX) HOT 디카페인 화이트 초콜릿 모카', '(EX) ICED 디카페인 화이트 초콜릿 모카', '(L) HOT 디카페인 민트 모카', '(L) ICED 디카페인 민트 모카', '(L) HOT 디카페인 카푸치노', '(L) ICED 디카페인 카푸치노', '(L) HOT 시그니처 라떼', '(EX) HOT 시그니처 라떼', '(L) ICED 시그니처 라떼', '(EX) ICED 시그니처 라떼', '(L) HOT 민트모히또 라떼', '(EX) HOT 민트모히또 라떼', '(L) ICED 민트모히또 라떼', '(EX) ICED 민트모히또 라떼', '(L) HOT  시그니처 라떼', '(EX) HOT 시그니처 라떼', '(L) ICED  시그니처 라떼', '(EX) ICED  시그니처 라떼', '(L) HOT 민트 모히또 라떼', '(EX) HOT 민트 모히또 라떼', '(L) ICED 민트 모히또 라떼', '(EX) ICED 민트 모히또 라떼', '(L) HOT 솔티 티라미수 라떼', '허니 생딸기 아이스크림', '(R) 아이스크림 딸기 라떼', '(R) HOT 레몬차', '(L) HOT 솔티 티라미수 라떼', '(L) ICED 솔티 티라미수 라떼', '(EX) HOT 솔티 티라미수 라떼', '(EX) ICED 솔티 티라미수 라떼', '(L) ICED 솔티 티라미수 라떼', '(EX) HOT 솔티 티라미수 라떼', '(EX) ICED 솔티 티라미수 라떼', '팥인절미 1인빙수', '(L) HOT 디카페인 카페 아메리카노', '(EX) HOT 디카페인 카페 아메리카노', '(R) 바닐라 오트 콜드브루', '(R) 디카페인 바닐라 오트 콜드브루', '(L) ICED 넛츠 크림 라떼', '(R) ICED 살얼음 식혜', '(EX) ICED 살얼음 식혜', '(R) HOT 그린 루이보스', '(R) ICED 그린 루이보스', '(EX) HOT 그린 루이보스', '(EX) ICED 그린 루이보스', '(R) HOT 샤인 히비스커스', '(R) ICED 샤인 히비스커스', '(EX) HOT 샤인 히비스커스', '(EX) ICED 샤인 히비스커스', '(R) HOT 스프링 캐모마일', '(R) ICED 스프링 캐모마일', '(EX) HOT 스프링 캐모마일', '(EX) ICED 스프링 캐모마일', '(R) HOT 퓨어 페퍼민트', '(R) ICED 퓨어 페퍼민트', '(EX) HOT 퓨어 페퍼민트', '(EX) ICED 퓨어 페퍼민트', '(R) HOT 피치 얼그레이', '(R) ICED 피치 얼그레이', '(EX) HOT 피치 얼그레이', '(EX) ICED 피치 얼그레이', '(R) HOT 쌍화차', '(R) ICED 쌍화차', '(R) HOT 생강차', '(R) ICED 생강차', '이디야 감귤&amp;한라봉 주스', '이디야 사과&amp;당근 주스', '이디야 워터', '(R) ICED 달고나 라떼', '(EX) ICED 달고나 라떼', '아포가토 오리지널', '디카페인 아포가토 오리지널', '이디야키즈 뽀로로 오렌지', '(R) 콜드브루 아메리카노', '이디야키즈 뽀로로 사과매실']
#
# ['홍차와 녹차의 추출액과 프락토올리고당, 스코비로 발효한 콤부차 원액과 정제수, 이디야의 노하우가 담긴 과일 티 농축액을 블렌딩하여 만든 프리바이오틱스를 함유한 병음료 콤부차 ', '홍차와 녹차의 추출액과 프락토올리고당, 스코비로 발효한 콤부차 원액과 정제수, 이디야의 노하우가 담긴 과일 티 농축액을 블렌딩하여 만든 프리바이오틱스를 함유한 병음료 콤부차 ', '홍차와 녹차의 추출액과 프락토올리고당, 스코비로 발효한 콤부차 원액과 정제수, 이디야의 노하우가 담긴 과일 티 농축액을 블렌딩하여 만든 프리바이오틱스를 함유한 병음료 콤부차 ', '홍차의 깊은 맛과 풍부한 복숭아 향이 어우러진 아이스티에 이디야 에스프레소가 어우러진 음료', '홍차의 깊은 맛과 풍부한 복숭아 향이 어우러진 아이스티에
.com/files/menu/IMG_1734051168883.png', 'https://ediya.com/files/menu/IMG_1734051249681.png', 'https://ediya.com/files/menu/IMG_1737091291443.png', 'https://ediya.com/files/menu/IMG_1737091304150.png', 'https://ediya.com/files/menu/IMG_1737091400359.png', 'https://ediya.com/files/menu/IMG_1737091480690.png', 'https://ediya.com/files/menu/IMG_1737091863415.png', 'https://ediya.com/files/menu/IMG_1737092138292.png', 'https://ediya.com/files/menu/IMG_1737092221128.png', 'https://ediya.com/files/menu/IMG_1737092309286.png', 'https://ediya.com/files/menu/IMG_1740122120271.png', 'https://ediya.com/files/menu/IMG_1740122228351.png', 'https://ediya.com/files/menu/IMG_1740122391612.png', 'https://ediya.com/files/menu/IMG_1740122496473.png', 'https://ediya.com/files/menu/IMG_1740122649397.png', 'https://ediya.com/files/menu/IMG_1740122749367.png', 'https://ediya.com/files/menu/IMG_1740123032766.png', 'https://ediya.com/files/menu/IMG_1740123139161.png', 'https://ediya.com/files/menu/IMG_1740124902418.png', 'https://ediya.com/files/menu/IMG_1740125032737.png', 'https://ediya.com/files/menu/IMG_1740125223233.png', 'https://ediya.com/files/menu/IMG_1740125308265.png', 'https://ediya.com/files/menu/IMG_1740125378335.png', 'https://ediya.com/files/menu/IMG_1740125445844.png', 'https://ediya.com/files/menu/IMG_1742278582482.png', 'https://ediya.com/files/menu/IMG_1742280705194.png', 'https://ediya.com/files/menu/IMG_1742279237605.png', 'https://ediya.com/files/menu/IMG_1742279437235.png', 'https://ediya.com/files/menu/IMG_1742279670528.png', 'https://ediya.com/files/menu/IMG_1742279746779.png', 'https://ediya.com/files/menu/IMG_1742280397600.png', 'https://ediya.com/files/menu/IMG_1742280497579.png', 'https://ediya.com/files/menu/IMG_1742280588417.png', 'https://ediya.com/files/menu/IMG_1742280670475.png', 'https://ediya.com/files/menu/IMG_1694414812893.png', 'https://ediya.com/files/menu/IMG_1694414794668.png', 'https://ediya.com/files/menu/IMG_1694414746800.png', 'https://ediya.com/files/menu/IMG_1694415549864.png', 'https://ediya.com/files/menu/IMG_1703040183528.png', 'https://ediya.com/files/menu/IMG_1703040302345.png', 'https://ediya.com/files/menu/IMG_1713744638856.png', 'https://ediya.com/files/menu/IMG_1713744897555.png', 'https://ediya.com/files/menu/IMG_1715911790197.png', 'https://ediya.com/files/menu/IMG_1715911919458.png', 'https://ediya.com/files/menu/IMG_1715912156628.png', 'ht ...

# %%
# ✅ DB 저장을 위한 데이터 준비
menu_data = []
cursor.execute("SELECT NVL(MAX(menu_id), 0) + 1 FROM MENU")  # 현재 최대 ID 가져오기
menu_id_start = cursor.fetchone()[0]

for i in range(len(db_name_list)):
    menu_data.append((menu_id_start + i, db_name_list[i], db_exp_list[i], None, "커피", db_img_list[i]))  # 가격은 NULL 처리

# 🔹 INSERT SQL 실행
insert_query = """
    INSERT INTO MENU (menu_id, menu_name, menu_info, menu_price, category, image)
    VALUES (:1, :2, :3, :4, :5, :6)
"""
cursor.executemany(insert_query, menu_data)

# 🔹 커밋 후 종료
conn.commit()
cursor.close()
conn.close()

print("✅ 데이터 저장 완료!")
# Out:
# ✅ 데이터 저장 완료!
